# %% [markdown]
# ## Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import math
import datetime
import requests
from config import *
from bs4 import BeautifulSoup
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
from time import sleep
from random import randint

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\31612\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\31612\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\31612\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\31612\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\31612\anaconda3\lib\site-packages (from spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\31612\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\31612\anaconda3\lib\site-packages (from spotipy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\31612\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\31612\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\31612\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.5.18.1)

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id,
                                                           client_secret= client_secret))

# %% [markdown]
# ## Creating search_song()

# %% [markdown]
# Create a function to search a given song in the Spotify API: search_song(). Take into account that sometimes Spotify's API will return several matches for the same song title (different artists, a different album of the same artist, version of the song,...etc). Then it will be nice to display a list of outputs to the user and let him/her select which is the right match. Once the desired song is located, the function should return the href/id/uri of the song to the code (not to the user).

# %%
billboard100 = pd.read_csv('billboard100.csv')

# %%
billboard100.head()
# Out:
#              title                         artist
# 0        As It Was                   Harry Styles
# 1      First Class                    Jack Harlow
# 2       Wait For U  Future Featuring Drake & Tems
# 3  About Damn Time                          Lizzo
# 4       Heat Waves                  Glass Animals

# %%
# %%writefile functions.py

import numpy as np
import pandas as pd
from time import sleep
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from config import *

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id,
                                                         client_secret= client_secret))

def search_song_ids(df, stepsize=20):
    
    song_ids = []
    
    for number in range(0,len(df),stepsize):
        print("Getting the song ids for the chunk:",number)
        print()
        for index in list(range(len(df)))[number:number+stepsize]:
            artist = df.iloc[index,1]
            title = df.iloc[index,0]
            try:
                results = sp.search(q="track:"+title+" artist:"+artist,limit=1)
                song_id = results['tracks']['items'][0]['id']
                song_ids.append(song_id)
            except:
                print("The song: {} of artist: {} is not on Spotify".format(title, artist))
                song_ids.append(np.nan)
        sleep(20)
        print()
        print()
    return song_ids
# Out:
# Overwriting functions.py

# %% [markdown]
# ### Applying search_song to the billboard dataset and dropping the missing values.

# %%
songs_ids_100 = search_song_ids(billboard100)
# Out:
# Getting the song ids for the chunk: 0
#
# The song: Wait For U of artist: Future Featuring Drake & Tems is not on Spotify
# The song: Me Porto Bonito of artist: Bad Bunny & Chencho Corleone is not on Spotify
# The song: Stay of artist: The Kid LAROI & Justin Bieber is not on Spotify
# The song: Enemy of artist: Imagine Dragons X JID is not on Spotify
#
#
# Getting the song ids for the chunk: 20
#
# The song: True Love of artist: Kanye West & XXXTENTACION is not on Spotify
# The song: Sweetest Pie of artist: Megan Thee Stallion & Dua Lipa is not on Spotify
# The song: Party of artist: Bad Bunny & Rauw Alejandro is not on Spotify
# The song: Bam Bam of artist: Camila Cabello Featuring Ed Sheeran is not on Spotify
# The song: MAMIII of artist: Becky G X Karol G is not on Spotify
# The song: Ojitos Lindos of artist: Bad Bunny & Bomba Estereo is not on Spotify
# The song: Cooped Up of artist: Post Malone Featuring Roddy Ricch is not on Spotify
#
#
# Getting the song ids for the chunk: 40
#
# The song: Sleazy Flow of artist: SleazyWorld Go Featuring Lil Baby is not on Spotify
# The song: 2step of artist: Ed Sheeran Featuring Lil Baby is not on Spotify
# The song: Die Young of artist: Sleepy Hallow Featuring 347aidan is not on Spotify
#
#
# Getting the song ids for the chunk: 60
#
# The song: Tarot of artist: Bad Bunny & Jhay Cortez is not on Spotify
# The song: What Happened To Virgil of artist: Lil Durk Featuring Gunna is not on Spotify
# The song: Never Say Never of artist: Cole Swindell / Lainey Wilson is not on Spotify
# The song: Freaky Deaky of artist: Tyga X Doja Cat is not on Spotify
# The song: Flower Shops of artist: ERNEST Featuring Morgan Wallen is not on Spotify
# The song: She Likes It of artist: Russell Dickerson & Jake Scott is not on Spotify
#
#
# Getting the song ids for the chunk: 80
#
# The song: La Corriente of artist: Bad Bunny & Tony Dize is not on Spotify
# The song: Sunroof of artist: Nicky Youre & dazy is not on Spotify
# The song: F.N.F. (Let's Go) of artist: Hitkidd & Glorilla is not on Spotify
# The song: Handsomer of artist: Russ Featuring Ktlyn is not on Spotify
# The song: I'm On One of artist: Future Featuring Drake is not on Spotify

# %%
display (songs_ids_100)
# Out:
# ['4LRPiXqCikLlN15c3yImP7',
#  '1rDQ4oMwGJI7B4tovsBOxc',
#  nan,
#  '1PckUlxKqWQs3RlWXVBLw3',
#  '3USxtqRwSYz57Ewm6wWRMp',
#  '6Zu3aw7FfjAF9WA0fA81Oq',
#  nan,
#  '29d0nY7TzCoi22XBqDQkiP',
#  '1qEmFfgcLObUfQm0j1W2CK',
#  nan,
#  '1IHWl5LamUGEuP4ozKQSXZ',
#  nan,
#  '3cBsEDNhFI9E82vPj3kvi3',
#  '6Xom58OOXk2SoU711L2IXO',
#  '6I3mqTwhRpn34SLVafSH7G',
#  '59CfNbkERJ3NoTXDvoURjj',
#  '6Uj1ctrBOjOas8xZXGqKk4',
#  '3rmo8F54jFF8OgYsqTxm5d',
#  '3o9kpgkIcffx0iSwxhuNI2',
#  '4A8cWXxKfIL3lAyUDzXbCF',
#  '5uU1uuyaUIBOiiUSQG7Wl3',
#  nan,
#  '2afB4eV1KWBqLqFqME6PTh',
#  '50nfwKoDiSYg8zOCREWAm5',
#  nan,
#  nan,
#  nan,
#  '0e8nrvls4Qqv5Rfa2UhqmO',
#  '6zSpb8dQRaw0M1dK8PBwQz',
#  '1dm6z1fWB0cErMszU25dy2',
#  '77oKig47u34qCCFWKMfu1e',
#  '3HO30hRbkOLU6ZWERayfQO',
#  '1qMMYpVatbRITKCfq1gasi',
#  '7dSZ6zGTQx66c2GF91xCrb',
#  nan,
#  nan,
#  nan,
#  '4k3lPl8YTKuY8c1HelVnm3',
#  '0fX4oNGBWO3dSGUZcVdVV2',
#  '3WMj8moIAXJhHsyLaqIIHI',
#  '5LYMamLv12UPbemOaTPyeV',
#  '6uvh0In7u1Xn4HgxOfAn8O',
#  '1r8ZCjfrQxoy2wVaBUbpwg',
#  '0IuVhCflrQPMGRrOyoY5RW',
#  '3ihIZrJreMJPjQdNLrEXnP',
#  '51Zw1cKDgkad0CXv23HCMU',
#  nan,
#  '4jp9FimhP2bQ93vR0A5r7b',
#  '0W6I02J9xcqK8MtSeosEXb',
#  '5Eax0qFko2dh7Rl2lYs3bx',
#  '3lzUeaCbcCDB5IXYfqWRlF',
#  '2g6tReTlM2Akp41g0HaeXN',
#  '0oWraSo5ASJ0h1BEagTyEw',
#  nan,
#  '5gVCfYmQRPy1QJifP8f5gg',
#  '3rF1pPjaDjWuIUCTXpMGIv',
#  '1fff5nZGyRJtFLkOrSSwOU',
#  '3i058E8uxTsYqJ5NWZzqSj',
#  '30vAfL9Wyu2fu07vdbZ1Xt',
#  nan,
#  '4j6kId9QIqhoXvqHKgSKa0',
#  '5CzixCxDkRXX9mScCmah8O',
#  nan,
#  '0U1W2LZVUX7qTm7dDpqxh6',
#  '0rzaRSujxA0bKyjJl6vHYq',
#  '3j1xkzTW8owIphkWV51V9s',
#  nan,
#  nan,
#  '6NHpyYvJyQsg2nXXzGYc2R',
#  '6F7UOC6fPWOkPqybOWBHSv',
#  '7fYRg3CEbk6rNCuzNzMT06',
#  '0QNNd0qMCDbraS1nQPg3aA',
#  '6ws54n2IzyrIxxyzlG2bVJ',
#  nan,
#  '35TyJIMR3xRouUuo2sjS6v',
#  '2NcQic8JxdjAlAHuNbOIRE',
#  '69w5X6uTrOaWM32IetSzvO',
#  '5kVZxyMY1gfdCLiChsfjn1',
#  nan,
#  nan,
#  '1mw0RgNXIpYRyyCdBQbLgA',
#  '2FGOg7uYBfnspkPOISXTFY',
#  '1QPreu0BNOrUfEb8HTd2qG',
#  nan,
#  '31i56LZnwE6uSu3exoHjtB',
#  '200x8ONbPfFzByUr3fVz46',
#  nan,
#  '6qj02zSeEJGWZ4c0dn5QzJ',
#  '13G5xv1wUKvJYbK0wYmioN',
#  '0LnS7aOdOdI1dNKZqdOLz4',
#  nan,
#  nan,
#  nan,
#  '1bdm32mVmoGcek5bVKxQKd',
#  '44XjoNvtwevktFKjvVe1vH',
#  '4XJRpBOG0bU3Nxnvam3FnC',
#  '0BQpyaFrb78b9uobWNheqx',
#  '3SeeaIXnrCfT88vHVCRWHl',
#  '7A4WmJcWx6KrVRfQ2CP8e7',
#  '0T5iIrXA4p5GsubkhuBIKV']

# %%
billboard100.shape
# Out:
# (100, 2)

# %%
billboard100.insert(loc=0, column='song_id', value=songs_ids_100)

# %%
billboard100.insert(loc=3 , column= 'dataset', value='H' )

# %%
billboard100.head()
# Out:
#                   song_id            title                         artist  \
# 0  4LRPiXqCikLlN15c3yImP7        As It Was                   Harry Styles
# 1  1rDQ4oMwGJI7B4tovsBOxc      First Class                    Jack Harlow
# 2                     NaN       Wait For U  Future Featuring Drake & Tems
# 3  1PckUlxKqWQs3RlWXVBLw3  About Damn Time                          Lizzo
# 4  3USxtqRwSYz57Ewm6wWRMp       Heat Waves                  Glass Animals
#
#   dataset
# 0       H
# 1       H
# 2       H
# 3       H
# 4       H

# %%
billboard100.dropna(inplace=True)

# %%
billboard100.shape
# Out:
# (75, 4)

# %% [markdown]
# ### Applying search_song to the not_hot dataset and dropping missing values

# %%
nothotsongs = pd.read_csv('not_hot_songs.csv')

# %%
songs_ids_nothot = search_song_ids(nothotsongs)
# Out:
# Getting the song ids for the chunk: 0
#
# The song: The Road Ahead (Miles Of The Unknown) of artist: City To City is not on Spotify
#
#
# Getting the song ids for the chunk: 20
#
# The song: Don't Know Why of artist: Norah Jones is not on Spotify
# The song: De Weg of artist: Guus Meeuwis is not on Spotify
#
#
# Getting the song ids for the chunk: 40
#
# The song: You're The First, The Last, My Everything of artist: Barry White is not on Spotify
# The song: Listen (From the Motion Picture "Dreamgirls") of artist: Beyoncé is not on Spotify
#
#
# Getting the song ids for the chunk: 60
#
#
#
# Getting the song ids for the chunk: 80
#
# The song: I'm Gonna Be (500 Miles) of artist: The Proclaimers is not on Spotify
#
#
# Getting the song ids for the chunk: 100
#
#
#
# Getting the song ids for the chunk: 120
#
# The song: You're the Voice of artist: John Farnham is not on Spotify
#
#
# Getting the song ids for the chunk: 140
#
#
#
# Getting the song ids for the chunk: 160
#
# The song: Like a Hurricane - 2003 Remaster of artist: Neil Young is not on Spotify
#
#
# Getting the song ids for the chunk: 180
#
# The song: (I've Had) The Time of My Life - From "Dirty Dancing" Soundtrack of artist: Bill Medley is not on Spotify
#
#
# Getting the song ids for the chunk: 200
#
# The song: Silence (feat. Sarah McLachlan) - DJ Tiësto's In Search of Sunrise Edit of artist: Delerium is not on Spotify
# The song: Can't Stop of artist: Red Hot Chili Peppers is not on Spotify
#
#
# Getting the song ids for the chunk: 220
#
#
#
# Getting the song ids for the chunk: 240
#
#
#
# Getting the song ids for the chunk: 260
#
# The song: Can't Stop Loving You - 2016 Remaster of artist: Phil Collins is not on Spotify
#
#
# Getting the song ids for the chunk: 280
#
# The song: Laat Me / Vivre - Lange Versie of artist: Alderliefste met Ramses Shaffy en Liesbeth List is not on Spotify
#
#
# Getting the song ids for the chunk: 300
#
#
#
# Getting the song ids for the chunk: 320
#
#
#
# Getting the song ids for the chunk: 340
#
# The song: Hallelujah of artist: Lisa Lois is not on Spotify
#
#
# Getting the song ids for the chunk: 360
#
#
#
# Getting the song ids for the chunk: 380
#
# The song: (You're The) Devil in Disguise of artist: Elvis Presley is not on Spotify
#
#
# Getting the song ids for the chunk: 400
#
#
#
# Getting the song ids for the chunk: 420
#
# The song: Rainbow In The Sky - K & A's Radio Blast of artist: DJ Paul Elstak is not on Spotify
#
#
# Getting the song ids for the chunk: 440
#
#
#
# Getting the song ids for the chunk: 460
#
# The song: I've Just Lost Somebody of artist: Golden Earring is not on Spotify
# The song: Skyfall - Full Length of artist: Adele is not on Spotify
#
#
# Getting the song ids for the chunk: 480
#
# The song: Zo Stil of artist: BLØF is not on Spotify
# The song: Video Games - Remastered of artist: Lana Del Rey is not on Spotify
# The song: Can't Hold Us - feat. Ray Dalton of artist: Macklemore & Ryan Lewis is not on Spotify
#
#
# Getting the song ids for the chunk: 500
#
# The song: Dodenrit of artist: Drs. P is not on Spotify
# The song: Zaterdag of artist: BLØF is not on Spotify
# The song: Later Als Ik Groter Ben of artist: BLØF is not on Spotify
#
#
# Getting the song ids for the chunk: 520
#
#
#
# Getting the song ids for the chunk: 540
#
# The song: Mijn Van Straat Geredde Roos of artist: De Dijk is not on Spotify
#
#
# Getting the song ids for the chunk: 560
#
# The song: In Your Arms of artist: Chef'Special is not on Spotify
#
#
# Getting the song ids for the chunk: 580
#
# The song: L'amour Toujours (Small Mix) of artist: Gigi D'Agostino is not on Spotify
#
#
# Getting the song ids for the chunk: 600
#
#
#
# Getting the song ids for the chunk: 620
#
#
#
# Getting the song ids for the chunk: 640
#
# The song: CAN'T STOP THE FEELING! (Original Song from DreamWorks Animation's "TROLLS") of artist: Justin Timberlake is not on Spotify
#
#
# Getting the song ids for the chunk: 660
#
# The song: The Life I Live of artist: Q'65 is not on Spotify
#
#
# Getting the song ids for the chunk: 680
#
# The song: Human of artist: Rag'n'Bone Man is not on Spotify
# The song: Roll Over Lay Down - Live At The Kursaal, Southend / 1975 of artist: Status Quo is not on Spotify
# The song: Amigo of artist: Chef'Special is not on Spotify
#
#
# Getting the song ids for the chunk: 700
#
# The song: Nicotine of artist: Chef'Special is not on Spotify
#
#
# Getting the song ids for the chunk: 720
#
# The song: Skin of artist: Rag'n'Bone Man is not on Spotify
#
#
# Getting the song ids for the chunk: 740
#
# The song: Welterusten Mijnheer De President of artist: Boudewijn de Groot is not on Spotify
# The song: Someone You Loved of artist: Lewis Capaldi is not on Spotify
#
#
# Getting the song ids for the chunk: 760
#
# The song: Een Meisje Van Zestien of artist: Boudewijn de Groot is not on Spotify
#
#
# Getting the song ids for the chunk: 780
#
# The song: Don't You (Forget About Me) of artist: Simple Minds is not on Spotify
# The song: The Load-Out - Remastered of artist: Jackson Browne is not on Spotify
# The song: Stay - Remastered of artist: Jackson Browne is not on Spotify
#
#
# Getting the song ids for the chunk: 800
#
# The song: Paranoid - 2016 Remaster of artist: Black Sabbath is not on Spotify
# The song: Who'll Stop The Rain of artist: Creedence Clearwater Revival is not on Spotify
# The song: Our House of artist: Crosby, Stills, Nash & Young is not on Spotify
# The song: Teach Your Children of artist: Crosby, Stills, Nash & Young is not on Spotify
# The song: Almost Cut My Hair of artist: Crosby, Stills, Nash & Young is not on Spotify
# The song: Since I've Been Loving You - 1990 Remaster of artist: Led Zeppelin is not on Spotify
#
#
# Getting the song ids for the chunk: 820
#
# The song: Working Class Hero - Remastered 2010 / Lennon Legend Version of artist: John Lennon is not on Spotify
# The song: Carry On of artist: Crosby, Stills, Nash & Young is not on Spotify
# The song: Southern Man - 2009 Remaster of artist: Neil Young is not on Spotify
#
#
# Getting the song ids for the chunk: 840
#
#
#
# Getting the song ids for the chunk: 860
#
# The song: You've Got a Friend of artist: James Taylor is not on Spotify
# The song: Won't Get Fooled Again - Original Album Version of artist: The Who is not on Spotify
#
#
# Getting the song ids for the chunk: 880
#
# The song: Heart of Gold - 2009 Remaster of artist: Neil Young is not on Spotify
# The song: You're so Vain of artist: Carly Simon is not on Spotify
#
#
# Getting the song ids for the chunk: 900
#
# The song: Harvest - 2009 Remaster of artist: Neil Young is not on Spotify
#
#
# Getting the song ids for the chunk: 920
#
# The song: Band On The Run - Remastered 2010 of artist: Paul McCartney is not on Spotify
# The song: Knockin' On Heaven's Door - Remastered of artist: Bob Dylan is not on Spotify
# The song: I'll Have To Say I Love You In A Song of artist: Jim Croce is not on Spotify
# The song: Don't Let Me Down - Remastered 2009 of artist: The Beatles is not on Spotify
#
#
# Getting the song ids for the chunk: 940
#
# The song: Killer Queen - 2011 Mix of artist: Queen is not on Spotify
#
#
# Getting the song ids for the chunk: 960
#
# The song: Can't Get It out of My Head of artist: Electric Light Orchestra is not on Spotify
# The song: Kashmir - 1990 Remaster of artist: Led Zeppelin is not on Spotify
# The song: I'm Not In Love of artist: 10cc is not on Spotify
#
#
# Getting the song ids for the chunk: 980
#
# The song: 39 - 2011 Mix of artist: Queen is not on Spotify
#
#
# Getting the song ids for the chunk: 1000
#
# The song: Somebody To Love - 2011 Mix of artist: Queen is not on Spotify
# The song: (Don't Fear) The Reaper of artist: Blue Öyster Cult is not on Spotify
#
#
# Getting the song ids for the chunk: 1020
#
#
#
# Getting the song ids for the chunk: 1040
#
# The song: Don't Stop - 2004 Remaster of artist: Fleetwood Mac is not on Spotify
#
#
# Getting the song ids for the chunk: 1060
#
# The song: Spread Your Wings - 2011 Mix of artist: Queen is not on Spotify
# The song: Isn't It Time of artist: The Babys is not on Spotify
#
#
# Getting the song ids for the chunk: 1080
#
# The song: Don't Stop Me Now - 2011 Mix of artist: Queen is not on Spotify
#
#
# Getting the song ids for the chunk: 1100
#
# The song: Don't Look Back of artist: Boston is not on Spotify
# The song: Born to Be Alive - Original Mix 79 of artist: Patrick Hernandez is not on Spotify
#
#
# Getting the song ids for the chunk: 1120
#
# The song: Don't Stop 'Til You Get Enough - Single Version of artist: Michael Jackson is not on Spotify
# The song: Don't Bring Me Down of artist: Electric Light Orchestra is not on Spotify
#
#
# Getting the song ids for the chunk: 1140
#
# The song: A Forest - Remastered Version of artist: The Cure is not on Spotify
#
#
# Getting the song ids for the chunk: 1160
#
#
#
# Getting the song ids for the chunk: 1180
#
# The song: Don't Stand So Close To Me of artist: The Police is not on Spotify
# The song: Don't Stop Believin' of artist: Journey is not on Spotify
#
#
# Getting the song ids for the chunk: 1200
#
# The song: Don't You Want Me of artist: The Human League is not on Spotify
# The song: I'll Find My Way Home - Remastered of artist: Jon & Vangelis is not on Spotify
#
#
# Getting the song ids for the chunk: 1220
#
#
#
# Getting the song ids for the chunk: 1240
#
# The song: I'm Still Standing of artist: Elton John is not on Spotify
#
#
# Getting the song ids for the chunk: 1260
#
# The song: Radio Ga Ga - 2011 Mix of artist: Queen is not on Spotify
# The song: I'm On Fire of artist: Bruce Springsteen is not on Spotify
#
#
# Getting the song ids for the chunk: 1280
#
#
#
# Getting the song ids for the chunk: 1300
#
# The song: Don't Answer Me of artist: The Alan Parsons Project is not on Spotify
#
#
# Getting the song ids for the chunk: 1320
#
#
#
# Getting the song ids for the chunk: 1340
#
# The song: Don't Give Up - 2012 Remaster of artist: Peter Gabriel is not on Spotify
#
#
# Getting the song ids for the chunk: 1360
#
# The song: Don't Leave Me This Way (with Sarah Jane Morris) of artist: The Communards is not on Spotify
# The song: I'll Be Over You of artist: TOTO is not on Spotify
#
#
# Getting the song ids for the chunk: 1380
#
# The song: Over De Muur of artist: Klein Orkest is not on Spotify
#
#
# Getting the song ids for the chunk: 1400
#
#
#
# Getting the song ids for the chunk: 1420
#
# The song: Laat Mij Maar Alleen of artist: Klein Orkest is not on Spotify
#
#
# Getting the song ids for the chunk: 1440
#
#
#
# Getting the song ids for the chunk: 1460
#
# The song: Personal Jesus - Original Seven Inch Version of artist: Depeche Mode is not on Spotify
#
#
# Getting the song ids for the chunk: 1480
#
#
#
# Getting the song ids for the chunk: 1500
#
# The song: Don't Go Breaking My Heart of artist: Elton John is not on Spotify
#
#
# Getting the song ids for the chunk: 1520
#
# The song: Deurdonderen of artist: Normaal is not on Spotify
# The song: The Show Must Go On - 2011 Mix of artist: Queen is not on Spotify
#
#
# Getting the song ids for the chunk: 1540
#
# The song: Don't Cry (Original) of artist: Guns N' Roses is not on Spotify
# The song: In Bloom - Nevermind Version of artist: Nirvana is not on Spotify
# The song: I'm Going Slightly Mad - Remastered 2011 of artist: Queen is not on Spotify
#
#
# Getting the song ids for the chunk: 1560
#
#
#
# Getting the song ids for the chunk: 1580
#
# The song: Harvest Moon of artist: Neil Young is not on Spotify
# The song: I've Got Dreams to Remember of artist: Otis Redding is not on Spotify
#
#
# Getting the song ids for the chunk: 1600
#
# The song: I'd Do Anything For Love (But I Won't Do That) - Single Edit of artist: Meat Loaf is not on Spotify
# The song: Gaia of artist: Valensia is not on Spotify
# The song: Mull Of Kintyre - 1993 Digital Remaster of artist: Wings is not on Spotify
#
#
# Getting the song ids for the chunk: 1620
#
#
#
# Getting the song ids for the chunk: 1640
#
# The song: Don't Look Back In Anger - Remastered of artist: Oasis is not on Spotify
#
#
# Getting the song ids for the chunk: 1660
#
# The song: Don't Speak of artist: No Doubt is not on Spotify
#
#
# Getting the song ids for the chunk: 1680
#
#
#
# Getting the song ids for the chunk: 1700
#
#
#
# Getting the song ids for the chunk: 1720
#
# The song: You'll Never Walk Alone of artist: Gerry & The Pacemakers is not on Spotify
#
#
# Getting the song ids for the chunk: 1740
#
# The song: N'oubliez Jamais of artist: Joe Cocker is not on Spotify
# The song: Can't Stand Losing You of artist: The Police is not on Spotify
# The song: Don't Let the Sun Go Down on Me of artist: George Michael is not on Spotify
#
#
# Getting the song ids for the chunk: 1760
#
# The song: I'm Not so Tough of artist: Ilse DeLange is not on Spotify
#
#
# Getting the song ids for the chunk: 1780
#
#
#
# Getting the song ids for the chunk: 1800
#
# The song: Harder Dan Ik Hebben Kan of artist: BLØF is not on Spotify
# The song: You'll Be In My Heart - From "Tarzan"/Soundtrack Version of artist: Phil Collins is not on Spotify
#
#
# Getting the song ids for the chunk: 1820
#
# The song: Don't Think Twice, It's All Right of artist: Bob Dylan is not on Spotify
#
#
# Getting the song ids for the chunk: 1840
#
#
#
# Getting the song ids for the chunk: 1860
#
#
#
# Getting the song ids for the chunk: 1880
#
# The song: Wouldn't It Be Nice - Stereo Mix of artist: The Beach Boys is not on Spotify
# The song: Nights In White Satin - Single Version / Mono Mix of artist: The Moody Blues is not on Spotify
#
#
# Getting the song ids for the chunk: 1900
#
# The song: Ain't No Mountain High Enough of artist: Marvin Gaye is not on Spotify
# The song: I'm a Believer - 2006 Remaster of artist: The Monkees is not on Spotify
#
#
# Getting the song ids for the chunk: 1920
#
# The song: What A Wonderful World - Single Version of artist: Louis Armstrong is not on Spotify
# The song: Ain't Got No - I Got Life - Remastered of artist: Nina Simone is not on Spotify
# The song: Massachussetts of artist: Bee Gees is not on Spotify
#
#
# Getting the song ids for the chunk: 1940
#
# The song: I'd Rather Go Blind of artist: Etta James is not on Spotify
#
#
# Getting the song ids for the chunk: 1960
#
# The song: Albatross - 2018 Remaster of artist: Fleetwood Mac is not on Spotify
#
#
# Getting the song ids for the chunk: 1980
#
# The song: Summertime of artist: Brainbox is not on Spotify
# The song: Black Magic Woman - 2018 Remaster of artist: Fleetwood Mac is not on Spotify
# The song: Suite: Judy Blue Eyes - Remastered of artist: Crosby, Stills & Nash is not on Spotify

# %%
nothotsongs.insert(loc=0, column='song_id', value=songs_ids_nothot)

# %%
nothotsongs.insert(loc=3 , column= 'dataset', value='NH' )

# %%
nothotsongs.dropna(inplace=True)

# %% [markdown]
# ## Creating "get_audio_features(list_of_songs)"

# %% [markdown]
# Create a function "get_audio_features(list_of_songs)" to obtain the audio features of a given list of songs (the content of list_of_songs can be the href/id/uri). Then, use this function to create a Pandas Dataframe with the audio features of the list of songs. Hint: create a dictionary with the song's audio features as keys and an empty list as values. Then fill in the lists with the corresponding audio features of each song. Finally, create your data frame from the dictionary. Bear in mind the following: This API has a restriction on the

# %%
# %%writefile -a functions.py

def get_audio_features(df, stepsize=20):
    
    song_features = []
    for number in range(0,len(df),stepsize):
        print("Getting the features for the chunk:",number)
        print()
        for index in list(range(len(df)))[number:number+stepsize]:
            song_id = df.iloc[index,0]
            try:
                my_dict = sp.audio_features(song_id)[0]
                song_features.append(my_dict)
                
            except:
                print("The features for {} are not in spotify".format(song_id))
                my_new_dict = {}
                song_features.append(my_new_dict)
        
                
        sleep(20)
        print()
        print()
    song_features = pd.DataFrame(song_features)
    return song_features
# Out:
# Appending to functions.py

# %% [markdown]
# ### Applying get_audio_features to billboard100

# %%
billboard100features = get_audio_features(billboard100)
# Out:
# Getting the features for the chunk: 0
#
#
#
# Getting the features for the chunk: 20
#
#
#
# Getting the features for the chunk: 40
#
#
#
# Getting the features for the chunk: 60

# %%
billboard100_final = pd.concat([billboard100.reset_index(), billboard100features], axis=1)
billboard100_final.drop(columns=['index', 'id'], inplace=True)
billboard100_final.head()
# Out:
#                   song_id            title         artist dataset  \
# 0  4LRPiXqCikLlN15c3yImP7        As It Was   Harry Styles       H
# 1  1rDQ4oMwGJI7B4tovsBOxc      First Class    Jack Harlow       H
# 2  1PckUlxKqWQs3RlWXVBLw3  About Damn Time          Lizzo       H
# 3  3USxtqRwSYz57Ewm6wWRMp       Heat Waves  Glass Animals       H
# 4  6Zu3aw7FfjAF9WA0fA81Oq       Big Energy          Latto       H
#
#    danceability  energy  key  loudness  mode  speechiness  ...  \
# 0         0.520   0.731    6    -5.338     0       0.0557  ...
# 1         0.905   0.563    8    -6.135     1       0.1020  ...
# 2         0.836   0.743   10    -6.305     0       0.0656  ...
# 3         0.761   0.525   11    -6.900     1       0.0944  ...
# 4         0.935   0.807   11    -3.838     0       0.1140  ...
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.001010    0.3110    0.662  173.930  audio_features
# 1          0.000010    0.1130    0.324  106.998  audio_features
# 2          0.000000    0.3350    0.722  108.966  audio_features
# 3          0.000007    0.0921    0.531   80.870  audio_features
# 4          0.000000    0.3490    0.813  106.017  audio_features
#
#                                     uri  \
# 0  spotify:track:4LRPiXqCikLlN15c3yImP7
# 1  spotify:track:1rDQ4oMwGJI7B4tovsBOxc
# 2  spotify:track:1PckUlxKqWQs3RlWXVBLw3
# 3  spotify:track:3USxtqRwSYz57Ewm6wWRMp
# 4  spotify:track:6Zu3aw7FfjAF9WA0fA81Oq
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4LRPiXqCikLl...
# 1  https://api.spotify.com/v1/tracks/1rDQ4oMwGJI7...
# 2  https://api.spotify.com/v1/tracks/1PckUlxKqWQs...
# 3  https://api.spotify.com/v1/tracks/3USxtqRwSYz5...
# 4  https://api.spotify.com/v1/tracks/6Zu3aw7FfjAF...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4LRP...      167303
# 1  https://api.spotify.com/v1/audio-analysis/1rDQ...      173948
# 2  https://api.spotify.com/v1/audio-analysis/1Pck...      191822
# 3  https://api.spotify.com/v1/audio-analysis/3USx...      238805
# 4  https://api.spotify.com/v1/audio-analysis/6Zu3...      173182
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %%
billboard100_final.to_csv('billboard100_final.csv', index=False)

# %% [markdown]
# ### Applying get_audio_features to nothotsongs

# %%
nothotsongsfeatures = get_audio_features(nothotsongs)
# Out:
# Getting the features for the chunk: 0
#
#
#
# Getting the features for the chunk: 20
#
#
#
# Getting the features for the chunk: 40
#
#
#
# Getting the features for the chunk: 60
#
#
#
# Getting the features for the chunk: 80
#
#
#
# Getting the features for the chunk: 100
#
#
#
# Getting the features for the chunk: 120
#
#
#
# Getting the features for the chunk: 140
#
#
#
# Getting the features for the chunk: 160
#
#
#
# Getting the features for the chunk: 180
#
#
#
# Getting the features for the chunk: 200
#
#
#
# Getting the features for the chunk: 220
#
#
#
# Getting the features for the chunk: 240
#
#
#
# Getting the features for the chunk: 260
#
#
#
# Getting the features for the chunk: 280
#
#
#
# Getting the features for the chunk: 300
#
#
#
# Getting the features for the chunk: 320
#
#
#
# Getting the features for the chunk: 340
#
#
#
# Getting the features for the chunk: 360
#
#
#
# Getting the features for the chunk: 380
#
#
#
# Getting the features for the chunk: 400
#
#
#
# Getting the features for the chunk: 420
#
#
#
# Getting the features for the chunk: 440
#
#
#
# Getting the features for the chunk: 460
#
#
#
# Getting the features for the chunk: 480
#
#
#
# Getting the features for the chunk: 500
#
#
#
# Getting the features for the chunk: 520
#
#
#
# Getting the features for the chunk: 540
#
#
#
# Getting the features for the chunk: 560
#
#
#
# Getting the features for the chunk: 580
#
#
#
# Getting the features for the chunk: 600
#
#
#
# Getting the features for the chunk: 620
#
#
#
# Getting the features for the chunk: 640
#
#
#
# Getting the features for the chunk: 660
#
#
#
# Getting the features for the chunk: 680
#
#
#
# Getting the features for the chunk: 700
#
#
#
# Getting the features for the chunk: 720
#
#
#
# Getting the features for the chunk: 740
#
#
#
# Getting the features for the chunk: 760
#
#
#
# Getting the features for the chunk: 780
#
#
#
# Getting the features for the chunk: 800
#
#
#
# Getting the features for the chunk: 820
#
#
#
# Getting the features for the chunk: 840
#
#
#
# Getting the features for the chunk: 860
#
#
#
# Getting the features for the chunk: 880
#
#
#
# Getting the features for the chunk: 900
#
#
#
# Getting the features for the chunk: 920
#
#
#
# Getting the features for the chunk: 940
#
#
#
# Getting the features for the chunk: 960
#
#
#
# Getting the features for the chunk: 980
#
#
#
# Getting the features for the chunk: 1000
#
#
#
# Getting the features for the chunk: 1020
#
#
#
# Getting the features for the chunk: 1040
#
#
#
# Getting the features for the chunk: 1060
#
#
#
# Getting the features for the chunk: 1080
#
#
#
# Getting the features for the chunk: 1100
#
#
#
# Getting the features for the chunk: 1120
#
#
#
# Getting the features for the chunk: 1140
#
#
#
# Getting the features for the chunk: 1160
#
#
#
# Getting the features for the chunk: 1180
#
#
#
# Getting the features for the chunk: 1200
#
#
#
# Getting the features for the chunk: 1220
#
#
#
# Getting the features for the chunk: 1240
#
#
#
# Getting the features for the chunk: 1260
#
#
#
# Getting the features for the chunk: 1280
#
#
#
# Getting the features for the chunk: 1300
#
#
#
# Getting the features for the chunk: 1320
#
#
#
# Getting the features for the chunk: 1340
#
#
#
# Getting the features for the chunk: 1360
#
#
#
# Getting the features for the chunk: 1380
#
#
#
# Getting the features for the chunk: 1400
#
#
#
# Getting the features for the chunk: 1420
#
#
#
# Getting the features for the chunk: 1440
#
#
#
# Getting the features for the chunk: 1460
#
#
#
# Getting the features for the chunk: 1480
#
#
#
# Getting the features for the chunk: 1500
#
#
#
# Getting the features for the chunk: 1520
#
#
#
# Getting the features for the chunk: 1540
#
#
#
# Getting the features for the chunk: 1560
#
#
#
# Getting the features for the chunk: 1580
#
#
#
# Getting the features for the chunk: 1600
#
#
#
# Getting the features for the chunk: 1620
#
#
#
# Getting the features for the chunk: 1640
#
#
#
# Getting the features for the chunk: 1660
#
#
#
# Getting the features for the chunk: 1680
#
#
#
# Getting the features for the chunk: 1700
#
#
#
# Getting the features for the chunk: 1720
#
#
#
# Getting the features for the chunk: 1740
#
#
#
# Getting the features for the chunk: 1760
#
#
#
# Getting the features for the chunk: 1780
#
#
#
# Getting the features for the chunk: 1800
#
#
#
# Getting the features for the chunk: 1820
#
#
#
# Getting the features for the chunk: 1840
#
#
#
# Getting the features for the chunk: 1860

# %%
nothotsongs_final = pd.concat([nothotsongs.reset_index(), nothotsongsfeatures], axis=1)
nothotsongs_final.drop(columns=['index', 'id'], inplace=True)
nothotsongs_final.head()
# Out:
#                   song_id                   title             artist dataset  \
# 0  7zkLpY72g6lKQbiHDqri1S                 Sunrise        Norah Jones      NH
# 1  7yn7rpRvg6XCq10B94etIp             Black Night        Deep Purple      NH
# 2  7yMiX7n9SBvadzox8T5jzT          Clint Eastwood           Gorillaz      NH
# 3  7x8dCjCr0x6x2lXKujYD34           The Pretender       Foo Fighters      NH
# 4  7vIyudiO2Tr9hZ2yzfwQmx  Waitin' On A Sunny Day  Bruce Springsteen      NH
#
#    danceability  energy  key  loudness  mode  speechiness  ...  \
# 0         0.526   0.299    8   -13.797     1       0.0310  ...
# 1         0.497   0.787    9   -11.039     1       0.0734  ...
# 2         0.663   0.694   10    -8.627     0       0.1710  ...
# 3         0.433   0.959    9    -4.040     1       0.0431  ...
# 4         0.584   0.820    0    -5.228     1       0.0271  ...
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.09700    0.1060    0.679  156.848  audio_features
# 1           0.52200    0.1700    0.812  134.598  audio_features
# 2           0.00000    0.0698    0.525  167.953  audio_features
# 3           0.00000    0.0280    0.365  172.984  audio_features
# 4           0.00004    0.0991    0.869  106.055  audio_features
#
#                                     uri  \
# 0  spotify:track:7zkLpY72g6lKQbiHDqri1S
# 1  spotify:track:7yn7rpRvg6XCq10B94etIp
# 2  spotify:track:7yMiX7n9SBvadzox8T5jzT
# 3  spotify:track:7x8dCjCr0x6x2lXKujYD34
# 4  spotify:track:7vIyudiO2Tr9hZ2yzfwQmx
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7zkLpY72g6lK...
# 1  https://api.spotify.com/v1/tracks/7yn7rpRvg6XC...
# 2  https://api.spotify.com/v1/tracks/7yMiX7n9SBva...
# 3  https://api.spotify.com/v1/tracks/7x8dCjCr0x6x...
# 4  https://api.spotify.com/v1/tracks/7vIyudiO2Tr9...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7zkL...      200627
# 1  https://api.spotify.com/v1/audio-analysis/7yn7...      207467
# 2  https://api.spotify.com/v1/audio-analysis/7yMi...      340920
# 3  https://api.spotify.com/v1/audio-analysis/7x8d...      269373
# 4  https://api.spotify.com/v1/audio-analysis/7vIy...      256133
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %%
nothotsongs_final.to_csv('nothotsongs_final.csv', index=False)

# %% [markdown]
# ## Creating "add_audio_features(df, audio_features_df)"

# %% [markdown]
# Once the previous function has been created, create another function "add_audio_features(df, audio_features_df)" to concat a given data frame with the data frame containing the audio features alongside any other desired info, and return the extended data frame.

# %% [markdown]
# Replace the old internal files of songs (hot and not hot) with the extended data frames with the audio features and save them into separate files on the disk.

# %% [markdown]
# def add_audio_features(df, audio_features_df):
#     dffinal = pandas.concat(df, audio_features_df, axis=1)
# return

# %%
# %%writefile -a functions.py
def add_audio_features(df, audio_features_df):
    df_final = pd.concat([df.reset_index(), audio_features_df], axis=1)
    df_final.drop(columns=['index', 'id'], inplace=True)
    return df_final
# Out:
# Appending to functions.py
