# %% [markdown]
# ## Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import math
import datetime
import requests
from config import *
from bs4 import BeautifulSoup
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
from time import sleep
from random import randint

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\31612\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\31612\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\31612\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\31612\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\31612\anaconda3\lib\site-packages (from spotipy) (1.26.9)
# Requirement already satisfied: requests>=2.25.0 in c:\users\31612\anaconda3\lib\site-packages (from spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\31612\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\31612\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\31612\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\31612\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id,
                                                           client_secret= client_secret))

# %% [markdown]
# ## Creating search_song()

# %% [markdown]
# Create a function to search a given song in the Spotify API: search_song(). Take into account that sometimes Spotify's API will return several matches for the same song title (different artists, a different album of the same artist, version of the song,...etc). Then it will be nice to display a list of outputs to the user and let him/her select which is the right match. Once the desired song is located, the function should return the href/id/uri of the song to the code (not to the user).

# %%
data = pd.read_csv('billboard100.csv')

# %%
data.head()
# Out:
#              title                         artist
# 0        As It Was                   Harry Styles
# 1      First Class                    Jack Harlow
# 2       Wait For U  Future Featuring Drake & Tems
# 3  About Damn Time                          Lizzo
# 4       Heat Waves                  Glass Animals

# %%
results = sp.search(q="track:"+"As it was"+" artist:"+"Harry Styles",limit=1)

# %%
results['tracks']['items'][0]['id']
# Out:
# '4LRPiXqCikLlN15c3yImP7'

# %%
def search_song_ids(df, stepsize=20):
    song_ids = []
    for number in range(0,len(df),stepsize):
        print("Getting the song ids for the chunk:",number)
        print()
        for index in list(range(len(df)))[number:number+stepsize]:
            artist = df.iloc[index,1]
            title = df.iloc[index,0]
            try:
                results = sp.search(q="track:"+title+" artist:"+artist,limit=1)
                song_id = results['tracks']['items'][0]['id']
                song_ids.append(song_id)
            except:
                print("The song: {} of artist: {} is not on Spotify".format(title, artist))
                song_ids.append(np.nan)
        sleep(20)
        print()
        print()
    return song_ids

# %%
songs_ids = search_song_ids(data)
# Out:
# Getting the song ids for the chunk: 0
#
# The song: Wait For U of artist: Future Featuring Drake & Tems is not on Spotify
# The song: Me Porto Bonito of artist: Bad Bunny & Chencho Corleone is not on Spotify
# The song: Stay of artist: The Kid LAROI & Justin Bieber is not on Spotify
# The song: Enemy of artist: Imagine Dragons X JID is not on Spotify
#
#
# Getting the song ids for the chunk: 20
#
# The song: True Love of artist: Kanye West & XXXTENTACION is not on Spotify
# The song: Sweetest Pie of artist: Megan Thee Stallion & Dua Lipa is not on Spotify
# The song: Party of artist: Bad Bunny & Rauw Alejandro is not on Spotify
# The song: Bam Bam of artist: Camila Cabello Featuring Ed Sheeran is not on Spotify
# The song: MAMIII of artist: Becky G X Karol G is not on Spotify
# The song: Ojitos Lindos of artist: Bad Bunny & Bomba Estereo is not on Spotify
# The song: Cooped Up of artist: Post Malone Featuring Roddy Ricch is not on Spotify
#
#
# Getting the song ids for the chunk: 40
#
# The song: Sleazy Flow of artist: SleazyWorld Go Featuring Lil Baby is not on Spotify
# The song: 2step of artist: Ed Sheeran Featuring Lil Baby is not on Spotify
# The song: Die Young of artist: Sleepy Hallow Featuring 347aidan is not on Spotify
#
#
# Getting the song ids for the chunk: 60
#
# The song: Tarot of artist: Bad Bunny & Jhay Cortez is not on Spotify
# The song: What Happened To Virgil of artist: Lil Durk Featuring Gunna is not on Spotify
# The song: Never Say Never of artist: Cole Swindell / Lainey Wilson is not on Spotify
# The song: Freaky Deaky of artist: Tyga X Doja Cat is not on Spotify
# The song: Flower Shops of artist: ERNEST Featuring Morgan Wallen is not on Spotify
# The song: She Likes It of artist: Russell Dickerson & Jake Scott is not on Spotify
#
#
# Getting the song ids for the chunk: 80
#
# The song: La Corriente of artist: Bad Bunny & Tony Dize is not on Spotify
# The song: Sunroof of artist: Nicky Youre & dazy is not on Spotify
# The song: F.N.F. (Let's Go) of artist: Hitkidd & Glorilla is not on Spotify
# The song: Handsomer of artist: Russ Featuring Ktlyn is not on Spotify
# The song: I'm On One of artist: Future Featuring Drake is not on Spotify

# %%
display (songs_ids)
# Out:
# ['4LRPiXqCikLlN15c3yImP7',
#  '1rDQ4oMwGJI7B4tovsBOxc',
#  nan,
#  '1PckUlxKqWQs3RlWXVBLw3',
#  '3USxtqRwSYz57Ewm6wWRMp',
#  '6Zu3aw7FfjAF9WA0fA81Oq',
#  nan,
#  '29d0nY7TzCoi22XBqDQkiP',
#  '1qEmFfgcLObUfQm0j1W2CK',
#  nan,
#  '1IHWl5LamUGEuP4ozKQSXZ',
#  nan,
#  '3cBsEDNhFI9E82vPj3kvi3',
#  '6Xom58OOXk2SoU711L2IXO',
#  '6I3mqTwhRpn34SLVafSH7G',
#  '59CfNbkERJ3NoTXDvoURjj',
#  '6Uj1ctrBOjOas8xZXGqKk4',
#  '3rmo8F54jFF8OgYsqTxm5d',
#  '3o9kpgkIcffx0iSwxhuNI2',
#  '4A8cWXxKfIL3lAyUDzXbCF',
#  '5uU1uuyaUIBOiiUSQG7Wl3',
#  nan,
#  '2afB4eV1KWBqLqFqME6PTh',
#  '50nfwKoDiSYg8zOCREWAm5',
#  nan,
#  nan,
#  nan,
#  '0e8nrvls4Qqv5Rfa2UhqmO',
#  '6zSpb8dQRaw0M1dK8PBwQz',
#  '1dm6z1fWB0cErMszU25dy2',
#  '77oKig47u34qCCFWKMfu1e',
#  '3HO30hRbkOLU6ZWERayfQO',
#  '1qMMYpVatbRITKCfq1gasi',
#  '7dSZ6zGTQx66c2GF91xCrb',
#  nan,
#  nan,
#  nan,
#  '4k3lPl8YTKuY8c1HelVnm3',
#  '0fX4oNGBWO3dSGUZcVdVV2',
#  '3WMj8moIAXJhHsyLaqIIHI',
#  '5LYMamLv12UPbemOaTPyeV',
#  '6uvh0In7u1Xn4HgxOfAn8O',
#  '1r8ZCjfrQxoy2wVaBUbpwg',
#  '0IuVhCflrQPMGRrOyoY5RW',
#  '3ihIZrJreMJPjQdNLrEXnP',
#  '51Zw1cKDgkad0CXv23HCMU',
#  nan,
#  '4jp9FimhP2bQ93vR0A5r7b',
#  '0W6I02J9xcqK8MtSeosEXb',
#  '5Eax0qFko2dh7Rl2lYs3bx',
#  '3lzUeaCbcCDB5IXYfqWRlF',
#  '2g6tReTlM2Akp41g0HaeXN',
#  '0oWraSo5ASJ0h1BEagTyEw',
#  nan,
#  '5gVCfYmQRPy1QJifP8f5gg',
#  '3rF1pPjaDjWuIUCTXpMGIv',
#  '1fff5nZGyRJtFLkOrSSwOU',
#  '3i058E8uxTsYqJ5NWZzqSj',
#  '30vAfL9Wyu2fu07vdbZ1Xt',
#  nan,
#  '4j6kId9QIqhoXvqHKgSKa0',
#  '5CzixCxDkRXX9mScCmah8O',
#  nan,
#  '0U1W2LZVUX7qTm7dDpqxh6',
#  '0rzaRSujxA0bKyjJl6vHYq',
#  '3j1xkzTW8owIphkWV51V9s',
#  nan,
#  nan,
#  '6NHpyYvJyQsg2nXXzGYc2R',
#  '6F7UOC6fPWOkPqybOWBHSv',
#  '7fYRg3CEbk6rNCuzNzMT06',
#  '0QNNd0qMCDbraS1nQPg3aA',
#  '6ws54n2IzyrIxxyzlG2bVJ',
#  nan,
#  '35TyJIMR3xRouUuo2sjS6v',
#  '2NcQic8JxdjAlAHuNbOIRE',
#  '69w5X6uTrOaWM32IetSzvO',
#  '5kVZxyMY1gfdCLiChsfjn1',
#  nan,
#  nan,
#  '1mw0RgNXIpYRyyCdBQbLgA',
#  '2FGOg7uYBfnspkPOISXTFY',
#  '1QPreu0BNOrUfEb8HTd2qG',
#  nan,
#  '31i56LZnwE6uSu3exoHjtB',
#  '200x8ONbPfFzByUr3fVz46',
#  nan,
#  '6qj02zSeEJGWZ4c0dn5QzJ',
#  '13G5xv1wUKvJYbK0wYmioN',
#  '0LnS7aOdOdI1dNKZqdOLz4',
#  nan,
#  nan,
#  nan,
#  '1bdm32mVmoGcek5bVKxQKd',
#  '44XjoNvtwevktFKjvVe1vH',
#  '4XJRpBOG0bU3Nxnvam3FnC',
#  '0BQpyaFrb78b9uobWNheqx',
#  '3SeeaIXnrCfT88vHVCRWHl',
#  '7A4WmJcWx6KrVRfQ2CP8e7',
#  '0T5iIrXA4p5GsubkhuBIKV']

# %%
data.insert(loc=0, column='song_id', value=songs_ids)

# %% [markdown]
# ## Creating "get_audio_features(list_of_songs)"

# %% [markdown]
# Create a function "get_audio_features(list_of_songs)" to obtain the audio features of a given list of songs (the content of list_of_songs can be the href/id/uri). Then, use this function to create a Pandas Dataframe with the audio features of the list of songs. Hint: create a dictionary with the song's audio features as keys and an empty list as values. Then fill in the lists with the corresponding audio features of each song. Finally, create your data frame from the dictionary. Bear in mind the following: This API has a restriction on the

# %% [markdown]
# song = sp.search(q="as it was", limit=1)
# #pprint.pprint(song['tracks']['items'][0]['uri'])
# song["tracks"]["items"][0]["uri"]
# sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's
#
# print(my_dict)
# my_dict_new = { key : [my_dict[key]] for key in list(my_dict.keys()) }
# #my_dict_new['name'] = [song["tracks"]["items"][0]['name']]
# print(my_dict_new)
#
#
# pd.DataFrame(my_dict_new)

# %%
def get_audio_features(df, stepsize=20):
    song_features = []
    for number in range(0,len(df),stepsize):
        print("Getting the features for the chunk:",number)
        print()
        for index in list(range(len(df)))[number:number+stepsize]:
            song_id = df.iloc[index,0]
            try:
                result= sp.audio_features(song_id)[0]
                my_dict = sp.audio_features(song_id)[0]
                my_new_dict = { key : [my_dict[key]] for key in list(my_dict.keys()) }
                print(my_new_dict)
                for dict in my_new_dict:
                    song_features.append(dict)
            except:
                print("These features are not in spotify")
                my_new_dict = { key : [np.nan] for key in list(my_dict.keys()) }
                for dict in my_new_dict:
                    song_features.append(dict)
                
        sleep(20)
        print()
        print()
        return song_features

# %%
get_audio_features(data)
# Out:
# Getting the features for the chunk: 0
#
# {'danceability': [0.52], 'energy': [0.731], 'key': [6], 'loudness': [-5.338], 'mode': [0], 'speechiness': [0.0557], 'acousticness': [0.342], 'instrumentalness': [0.00101], 'liveness': [0.311], 'valence': [0.662], 'tempo': [173.93], 'type': ['audio_features'], 'id': ['4LRPiXqCikLlN15c3yImP7'], 'uri': ['spotify:track:4LRPiXqCikLlN15c3yImP7'], 'track_href': ['https://api.spotify.com/v1/tracks/4LRPiXqCikLlN15c3yImP7'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/4LRPiXqCikLlN15c3yImP7'], 'duration_ms': [167303], 'time_signature': [4]}
# {'danceability': [0.905], 'energy': [0.563], 'key': [8], 'loudness': [-6.135], 'mode': [1], 'speechiness': [0.102], 'acousticness': [0.0254], 'instrumentalness': [9.71e-06], 'liveness': [0.113], 'valence': [0.324], 'tempo': [106.998], 'type': ['audio_features'], 'id': ['1rDQ4oMwGJI7B4tovsBOxc'], 'uri': ['spotify:track:1rDQ4oMwGJI7B4tovsBOxc'], 'track_href': ['https://api.spotify.com/v1/tracks/1rDQ4oMwGJI7B4tovsBOxc'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/1rDQ4oMwGJI7B4tovsBOxc'], 'duration_ms': [173948], 'time_signature': [4]}
# These features are not in spotify
# {'danceability': [0.836], 'energy': [0.743], 'key': [10], 'loudness': [-6.305], 'mode': [0], 'speechiness': [0.0656], 'acousticness': [0.0995], 'instrumentalness': [0], 'liveness': [0.335], 'valence': [0.722], 'tempo': [108.966], 'type': ['audio_features'], 'id': ['1PckUlxKqWQs3RlWXVBLw3'], 'uri': ['spotify:track:1PckUlxKqWQs3RlWXVBLw3'], 'track_href': ['https://api.spotify.com/v1/tracks/1PckUlxKqWQs3RlWXVBLw3'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/1PckUlxKqWQs3RlWXVBLw3'], 'duration_ms': [191822], 'time_signature': [4]}
# {'danceability': [0.761], 'energy': [0.525], 'key': [11], 'loudness': [-6.9], 'mode': [1], 'speechiness': [0.0944], 'acousticness': [0.44], 'instrumentalness': [6.7e-06], 'liveness': [0.0921], 'valence': [0.531], 'tempo': [80.87], 'type': ['audio_features'], 'id': ['3USxtqRwSYz57Ewm6wWRMp'], 'uri': ['spotify:track:3USxtqRwSYz57Ewm6wWRMp'], 'track_href': ['https://api.spotify.com/v1/tracks/3USxtqRwSYz57Ewm6wWRMp'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/3USxtqRwSYz57Ewm6wWRMp'], 'duration_ms': [238805], 'time_signature': [4]}
# {'danceability': [0.935], 'energy': [0.807], 'key': [11], 'loudness': [-3.838], 'mode': [0], 'speechiness': [0.114], 'acousticness': [0.0514], 'instrumentalness': [0], 'liveness': [0.349], 'valence': [0.813], 'tempo': [106.017], 'type': ['audio_features'], 'id': ['6Zu3aw7FfjAF9WA0fA81Oq'], 'uri': ['spotify:track:6Zu3aw7FfjAF9WA0fA81Oq'], 'track_href': ['https://api.spotify.com/v1/tracks/6Zu3aw7FfjAF9WA0fA81Oq'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/6Zu3aw7FfjAF9WA0fA81Oq'], 'duration_ms': [173182], 'time_signature': [4]}
# These features are not in spotify
# {'danceability': [0.625], 'energy': [0.533], 'key': [10], 'loudness': [-11.903], 'mode': [0], 'speechiness': [0.0596], 'acousticness': [0.659], 'instrumentalness': [0.00266], 'liveness': [0.0546], 'valence': [0.139], 'tempo': [108.296], 'type': ['audio_features'], 'id': ['29d0nY7TzCoi22XBqDQkiP'], 'uri': ['spotify:track:29d0nY7TzCoi22XBqDQkiP'], 'track_href': ['https://api.spotify.com/v1/tracks/29d0nY7TzCoi22XBqDQkiP'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/29d0nY7TzCoi22XBqDQkiP'], 'duration_ms': [300840], 'time_signature': [4]}
# {'danceability': [0.714], 'energy': [0.728], 'key': [10], 'loudness': [-4.595], 'mode': [1], 'speechiness': [0.0468], 'acousticness': [0.298], 'instrumentalness': [0], 'liveness': [0.106], 'valence': [0.901], 'tempo': [114.996], 'type': ['audio_features'], 'id': ['1qEmFfgcLObUfQm0j1W2CK'], 'uri': ['spotify:track:1qEmFfgcLObUfQm0j1W2CK'], 'track_href': ['https://api.spotify.com/v1/tracks/1qEmFfgcLObUfQm0j1W2CK'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/1qEmFfgcLObUfQm0j1W2CK'], 'duration_ms': [177955], 'time_signature': [4]}
# These features are not in spotify
# {'danceability': [0.65], 'energy': [0.715], 'key': [5], 'loudness': [-5.198], 'mode': [0], 'speechiness': [0.253], 'acousticness': [0.0993], 'instrumentalness': [0.000291], 'liveness': [0.126], 'valence': [0.187], 'tempo': [106.672], 'type': ['audio_features'], 'id': ['1IHWl5LamUGEuP4ozKQSXZ'], 'uri': ['spotify:track:1IHWl5LamUGEuP4ozKQSXZ'], 'track_href': ['https://api.spotify.com/v1/tracks/1IHWl5LamUGEuP4ozKQSXZ'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/1IHWl5LamUGEuP4ozKQSXZ'], 'duration_ms': [243717], 'time_signature': [4]}
# These features are not in spotify
# {'danceability': [0.505], 'energy': [0.657], 'key': [11], 'loudness': [-5.24], 'mode': [0], 'speechiness': [0.0318], 'acousticness': [0.373], 'instrumentalness': [0.00107], 'liveness': [0.126], 'valence': [0.252], 'tempo': [196.0], 'type': ['audio_features'], 'id': ['3cBsEDNhFI9E82vPj3kvi3'], 'uri': ['spotify:track:3cBsEDNhFI9E82vPj3kvi3'], 'track_href': ['https://api.spotify.com/v1/tracks/3cBsEDNhFI9E82vPj3kvi3'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/3cBsEDNhFI9E82vPj3kvi3'], 'duration_ms': [178520], 'time_signature': [3]}
# {'danceability': [0.804], 'energy': [0.674], 'key': [5], 'loudness': [-5.453], 'mode': [0], 'speechiness': [0.0333], 'acousticness': [0.294], 'instrumentalness': [1.18e-06], 'liveness': [0.115], 'valence': [0.292], 'tempo': [99.968], 'type': ['audio_features'], 'id': ['6Xom58OOXk2SoU711L2IXO'], 'uri': ['spotify:track:6Xom58OOXk2SoU711L2IXO'], 'track_href': ['https://api.spotify.com/v1/tracks/6Xom58OOXk2SoU711L2IXO'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/6Xom58OOXk2SoU711L2IXO'], 'duration_ms': [245940], 'time_signature': [4]}
# {'danceability': [0.601], 'energy': [0.741], 'key': [2], 'loudness': [-5.569], 'mode': [1], 'speechiness': [0.0478], 'acousticness': [0.185], 'instrumentalness': [2.91e-05], 'liveness': [0.415], 'valence': [0.441], 'tempo': [153.96], 'type': ['audio_features'], 'id': ['6I3mqTwhRpn34SLVafSH7G'], 'uri': ['spotify:track:6I3mqTwhRpn34SLVafSH7G'], 'track_href': ['https://api.spotify.com/v1/tracks/6I3mqTwhRpn34SLVafSH7G'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/6I3mqTwhRpn34SLVafSH7G'], 'duration_ms': [153190], 'time_signature': [4]}
# {'danceability': [0.345], 'energy': [0.612], 'key': [7], 'loudness': [-6.543], 'mode': [0], 'speechiness': [0.0608], 'acousticness': [0.232], 'instrumentalness': [0], 'liveness': [0.194], 'valence': [0.232], 'tempo': [179.773], 'type': ['audio_features'], 'id': ['59CfNbkERJ3NoTXDvoURjj'], 'uri': ['spotify:track:59CfNbkERJ3NoTXDvoURjj'], 'track_href': ['https://api.spotify.com/v1/tracks/59CfNbkERJ3NoTXDvoURjj'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/59CfNbkERJ3NoTXDvoURjj'], 'duration_ms': [153000], 'time_signature': [3]}
# {'danceability': [0.824], 'energy': [0.764], 'key': [5], 'loudness': [-4.175], 'mode': [0], 'speechiness': [0.0854], 'acousticness': [0.0888], 'instrumentalness': [0.00294], 'liveness': [0.117], 'valence': [0.881], 'tempo': [107.998], 'type': ['audio_features'], 'id': ['6Uj1ctrBOjOas8xZXGqKk4'], 'uri': ['spotify:track:6Uj1ctrBOjOas8xZXGqKk4'], 'track_href': ['https://api.spotify.com/v1/tracks/6Uj1ctrBOjOas8xZXGqKk4'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/6Uj1ctrBOjOas8xZXGqKk4'], 'duration_ms': [172627], 'time_signature': [4]}
# {'danceability': [0.807], 'energy': [0.893], 'key': [11], 'loudness': [-3.745], 'mode': [0], 'speechiness': [0.0347], 'acousticness': [0.0451], 'instrumentalness': [2.79e-05], 'liveness': [0.366], 'valence': [0.537], 'tempo': [126.011], 'type': ['audio_features'], 'id': ['3rmo8F54jFF8OgYsqTxm5d'], 'uri': ['spotify:track:3rmo8F54jFF8OgYsqTxm5d'], 'track_href': ['https://api.spotify.com/v1/tracks/3rmo8F54jFF8OgYsqTxm5d'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/3rmo8F54jFF8OgYsqTxm5d'], 'duration_ms': [230747], 'time_signature': [4]}
# {'danceability': [0.742], 'energy': [0.527], 'key': [8], 'loudness': [-6.892], 'mode': [0], 'speechiness': [0.0769], 'acousticness': [0.327], 'instrumentalness': [0], 'liveness': [0.25], 'valence': [0.638], 'tempo': [84.974], 'type': ['audio_features'], 'id': ['3o9kpgkIcffx0iSwxhuNI2'], 'uri': ['spotify:track:3o9kpgkIcffx0iSwxhuNI2'], 'track_href': ['https://api.spotify.com/v1/tracks/3o9kpgkIcffx0iSwxhuNI2'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/3o9kpgkIcffx0iSwxhuNI2'], 'duration_ms': [169238], 'time_signature': [4]}
# {'danceability': [0.825], 'energy': [0.414], 'key': [2], 'loudness': [-6.634], 'mode': [1], 'speechiness': [0.144], 'acousticness': [0.00265], 'instrumentalness': [0], 'liveness': [0.357], 'valence': [0.106], 'tempo': [72.993], 'type': ['audio_features'], 'id': ['4A8cWXxKfIL3lAyUDzXbCF'], 'uri': ['spotify:track:4A8cWXxKfIL3lAyUDzXbCF'], 'track_href': ['https://api.spotify.com/v1/tracks/4A8cWXxKfIL3lAyUDzXbCF'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/4A8cWXxKfIL3lAyUDzXbCF'], 'duration_ms': [200548], 'time_signature': [4]}
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature']

# %% [markdown]
# ## Creating "add_audio_features(df, audio_features_df)"

# %% [markdown]
# Once the previous function has been created, create another function "add_audio_features(df, audio_features_df)" to concat a given data frame with the data frame containing the audio features alongside any other desired info, and return the extended data frame.

# %% [markdown]
# Replace the old internal files of songs (hot and not hot) with the extended data frames with the audio features and save them into separate files on the disk.

# %%
song_features.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 song_features
#
# NameError: name 'song_features' is not defined

# %% [markdown]
# ## Clustering the songs

# %% [markdown]
# Now it's time to cluster the songs of the hot_songs and not_hot_songs databases according to the song's audio features. You will need to consider the following:
#
# Are you going to use all the audio features? If not, which ones do you think to make more sense?
# What is the optimal number of clusters (for methods that need to know this beforehand)?
# What is the best distance to use?
# What clustering method provides better results?
# Does the clustering method need a transformer?
# Be aware that this process is extremely time-consuming!!! Therefore, when testing different options, save the models into your disk in order to be able to use the best model later.  You don't want to retrain the best model again when you know what are the optimal parameters for each.
#
# Add to the hot_songs and not_hot_songs databases a new column for each clustering method with the cluster membership of each song for each method.
